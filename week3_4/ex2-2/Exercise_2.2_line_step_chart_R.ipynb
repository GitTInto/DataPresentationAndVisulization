# %% [markdown]
# ### Exercise_2.2_line_step_chart_R

# %%
# Loading
library("readxl")
library(ggplot2)
library(dplyr)
# xls files
my_data <- read_excel("./world-population.xlsm")

# %%
print(my_data)
# Out:
# # A tibble: 50 x 2
#     Year Population
#    <dbl>      <dbl>
#  1  1960 3028654024
#  2  1961 3068356747
#  3  1962 3121963107
#  4  1963 3187471383
#  5  1964 3253112403
#  6  1965 3320396924
#  7  1966 3390712300
#  8  1967 3460521851
#  9  1968 3531547287
# 10  1969 3606994959
# # … with 40 more rows

# %%
# Plot
ggplot(my_data, aes(x=Year, y=Population)) +
  geom_line() + ggtitle("Population Vs Year")
# Out:
# plot without title

# %%
ggplot(my_data , aes(x=Year, y=Population)) +
geom_step() + 
ggtitle("Population Vs Year")
# Out:
# plot without title
